# %%
# Домашняя работа № 18

# Преподаватель: Александр Кондрашкин

# ПАКЕТ SURPRISE

# − используйте данные MovieLens 1M
# − можно использовать любые модели из пакета
# − получите RMSE на тестовом сете 0.87 и ниже

# Решением будет ссылка на гитхаб с готовым ноутбуком

# %%
from surprise import , KNNBasic, KNNWithZScore, SVD, SVDpp, NMF, CoClustering, SlopeOne
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV

import pandas as pd

# %%
#Загрузим данные

data = Dataset.load_builtin(name=u'ml-1m')
data_small = Dataset.load_builtin(name=u'ml-100k')
trainset, testset = train_test_split(data, test_size=.15)
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /home/user/.surprise_data/ml-100k

# %%
#   для получения предсказания используем различные алгоритмы

#   за адекватное время сработали алгоритмы 
#   KNNWithMeans, KNNBasic, KNNWithZScore, SVD,  NMF, CoClustering, SlopeOne

#   Проведя предсказания, отберем удовлетворяющие условию RMSE < 0.87

#   после усредним предсказания 


# Сделаем предположение,
# что для датасетов разного размера оптимальные гипер параметры  будут примерно одинаковые

# и тогда исходя из этого допущения подбирать гипер параметры будем на датасете ml-100k

# %%
# KNNBasic
param_grid = {'k':[40,50,60], 
              'bsl_options': {'method':['als','sgd'] },
              'sim_options': {'name': ['cosine','msd','pearson','pearson_baseline'],
                              'user_based': [False, True]}
             }
gs = GridSearchCV(KNNBasic, param_grid, measures=['rmse', 'mae'], cv=3,joblib_verbose=False)

gs.fit(data_small)

print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# ...

# %%
algo = KNNBasic(k=30,
                     bsl_options={'method':'als'},
                     sim_options={'name': 'msd', 'user_based': False})
algo.fit(trainset)
test_pred_knnbasic = algo.test(testset)
accuracy.rmse(test_pred_knnbasic, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9106
# 0.910648772789083

# %%
#KNNWithMeans

param_grid = {'k':[40,50,60], 
              'bsl_options': {'method':['als','sgd'] },
              'sim_options': {'name': ['cosine','msd','pearson','pearson_baseline'],
                              'user_based': [False, True]}
             }
gs = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=3, joblib_verbose=0)

gs.fit(data_small)

print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# ...

# %%
#KNNWithMeans

algo = KNNWithMeans(k=50,
                     bsl_options={'method':'als' },
                     sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
test_pred_knnmean = algo.test(testset)
accuracy.rmse(test_pred_knnmean, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8573
# 0.8573205145919092

# %%
# KNNWithZScore
param_grid = {'k':[40,50,60], 
              'bsl_options': {'method':['als','sgd'] },
              'sim_options': {'name': ['cosine','msd','pearson','pearson_baseline'],
                              'user_based': [False, True]}
             }
gs = GridSearchCV(KNNWithZScore, param_grid, measures=['rmse', 'mae'], cv=3, joblib_verbose=0)

gs.fit(data_small)

print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# ...

# %%
# KNNWithZScore

algo = KNNWithZScore(k=50,
                     bsl_options={'method':'als' },
                     sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
test_pred_knnZ = algo.test(testset)
accuracy.rmse(test_pred_knnZ, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8577
# 0.8577159464500504

# %%
# SVD

algo = SVD()
algo.fit(trainset)
test_pred_svd = algo.test(testset)
accuracy.rmse(test_pred_svd, verbose=True)
# Out:
# RMSE: 0.8699
# 0.8698698813239144

# %%
# NMF

algo = NMF()
algo.fit(trainset)
test_pred_NMF = algo.test(testset)
accuracy.rmse(test_pred_NMF, verbose=True)
# Out:
# RMSE: 0.9176
# 0.9176320543050115

# %%
param_grid = {'n_cltr_u':[6,7,8], 
              'n_cltr_i': [1,2,3,4,5,6],
              'n_epochs':[30, 40]
             }
gs = GridSearchCV(CoClustering, param_grid, measures=['rmse', 'mae'], cv=3, joblib_verbose=0)

gs.fit(data_small)

print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# 0.9578695003715506
# {'n_cltr_u': 6, 'n_cltr_i': 2, 'n_epochs': 30}

# %%
# CoClustering

algo = CoClustering(n_cltr_u = 6, n_cltr_i=2,n_epochs=30 )
algo.fit(trainset)
test_pred_cc = algo.test(testset)
accuracy.rmse(test_pred_cc, verbose=True)
# Out:
# RMSE: 0.9146
# 0.9145623707665061

# %%
# SlopeOne

algo = SlopeOne()
algo.fit(trainset)
test_pred_sl = algo.test(testset)
accuracy.rmse(test_pred_sl, verbose=True)
# Out:
# RMSE: 0.9072
# 0.9072106418660841

# %%
# Соединим предсказания моделей подходящих по параметру RMSE < 0.87

import numpy as np
from sklearn.metrics import mean_squared_error

test = [[x.est for x in pred] for pred in [test_pred_svd, test_pred_knnZ, test_pred_knnmean]]
test_true = [[x.r_ui for x in pred] for pred in [test_pred_sl]]

np_test = np.mean(np.array(test), axis=0)
np_test_true = np.mean(np.array(test_true), axis=0)

rmse = np.sqrt(mean_squared_error(np_test_true, np_test))

print(f'RMSE: {rmse}')
# Out:
# RMSE: 0.852410954669175
